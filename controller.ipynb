# %% [markdown]
# # Controller

# %% [markdown]
# This notebook is responsible for integrating all the notebooks present in this project
#
# When executed, this notebook automaticall runs all other notebooks sequantially.

# %%
# Importing important libraries

import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim

#Resizing the Plots
plt.rcParams["figure.figsize"] = (12, 12)

# %%
# %store -z  # Deleting all pre- stored variables

# %%
# Running gui_1.ipynb

# %run ./gui_1.ipynb
# Out:
# C:/Users/itzme/OneDrive/Documents/Project FIles/Fake-Currency-Detection-System-main/Project_files/Fake Notes/500/500_f1.jpg
# 1
# Stored 'selectedImage' (bool)
# Stored 'path' (str)
# Stored 'option' (int)

# %%
# The GUI file produces and then stores the variables path and option
# Reading the stored variables

# %store -r selectedImage
# %store -r path
# %store -r option

print('Image selected: ', selectedImage)
print('Path: ', path)
print('Currency type: ', option)
# Out:
# Image selected:  True
# Path:  C:/Users/itzme/OneDrive/Documents/Project FIles/Fake-Currency-Detection-System-main/Project_files/Fake Notes/500/500_f1.jpg
# Currency type:  1

# %%
if selectedImage == True:
    if option == 1:                        # For 500 currency note
        # %run ./500_Testing.ipynb
    elif option == 2:                      # For 2000 currency note
        # %run ./2000_Testing.ipynb
# Out:
# Path of input image:  C:/Users/itzme/OneDrive/Documents/Project FIles/Fake-Currency-Detection-System-main/Project_files/Fake Notes/500/500_f1.jpg
# ANALYSIS OF FEATURE 1
# ---> Template 1 :
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\itzme\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\itzme\AppData\Local\Temp\ipykernel_19448\3328779256.py", line 8, in Testing
#     testFeature_1_2_7()
#   File "C:\Users\itzme\AppData\Local\Temp\ipykernel_19448\3423155713.py", line 34, in testFeature_1_2_7
#     template_img_blur = cv2.GaussianBlur(template_img, (5,5), 0)
# cv2.error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\smooth.dispatch.cpp:617: error: (-215:Assertion failed) !_src.empty() in function 'cv::GaussianBlur'
# Stored 'result_list' (list)

# %%
if selectedImage == True:
    # The above file produces and stores result_list variable
    # Reading the variable
    # %store -r result_list

    # Showing the results
    # The result list variable is a list of lists and each list conatins details about each feature
    for x in result_list:
        if x[0] is not None:            
            plt.imshow(x[0])   # Showing images
            plt.show()

# %%
if selectedImage == True:
# Show output in GUI

    # %run ./gui_2.ipynb
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_19448\717574210.py:214, in <cell line: 214>()
#     211 master_frame.bind("<Configure>",scrollbar_function)
#     213 # Displaying output
# --> 214 display_output()
#     216 # Open the root window and loop
#     217 root.mainloop()
#
# File ~\AppData\Local\Temp\ipykernel_19448\717574210.py:81, in display_output()
#      78 canvas = Canvas(master=frame2, width = 200, height = 200)
#      79 canvas.pack()
# ---> 81 image = result_list[feature_num][0].copy()
#      83 h, w = image.shape[:2]
#      84 aspect_ratio = w/h
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
#       1 if selectedImage == True:
#       2 # Show output in GUI
# ----> 4     get_ipython().run_line_magic('run', './gui_2.ipynb')
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2294, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2292     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2293 with self.builtin_trap:
# -> 2294     result = fn(*args, **kwargs)
#    2295 return result
#
# File ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py:717, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     with preserve_keys(self.shell.user_ns, '__file__'):
#     716         self.shell.user_ns['__file__'] = filename
# --> 717         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     718     return
#     720 # Control the response to exit() calls made by the script being run
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2800, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2798 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2799 if raise_exceptions:
# -> 2800     result.raise_error()
#    2801 elif not result.success:
#    2802     break
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:240, in ExecutionResult.raise_error(self)
#     238     raise self.error_before_exec
#     239 if self.error_in_exec is not None:
# --> 240     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_19448\717574210.py:214, in <cell line: 214>()
#     211 master_frame.bind("<Configure>",scrollbar_function)
#     213 # Displaying output
# --> 214 display_output()
#     216 # Open the root window and loop
#     217 root.mainloop()
#
# File ~\AppData\Local\Temp\ipykernel_19448\717574210.py:81, in display_output()
#      78 canvas = Canvas(master=frame2, width = 200, height = 200)
#      79 canvas.pack()
# ---> 81 image = result_list[feature_num][0].copy()
#      83 h, w = image.shape[:2]
#      84 aspect_ratio = w/h
#
# IndexError: list index out of range

# %%
# %store -z  # Deleting all pre- stored variables
